# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
from scipy import sparse
from sklearn.metrics import pairwise_distances   # Take care of all those cosine equations

# %% [markdown]
# # Load Data Frames

# %%
movies = pd.read_csv('movies.dat', sep = '::', names=['movieId', 'title', 'categories'])
movies.head()
# Out:
# /Users/Bolito/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#    movieId                               title                    categories
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy

# %%
ratings = pd.read_csv('ratings.dat', sep = '::', names=['userId', 'movieId', 'ratings', 'timestape'])
ratings.head()
# Out:
# /Users/Bolito/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#    userId  movieId  ratings  timestape
# 0       1     1193        5  978300760
# 1       1      661        3  978302109
# 2       1      914        3  978301968
# 3       1     3408        4  978300275
# 4       1     2355        5  978824291

# %% [markdown]
# # Drop 'categories' and 'timestape' column from movies and ratings respectively

# %%
movies.drop('categories', axis =1, inplace = True)

ratings.drop('timestape', axis =1, inplace = True)

movies.head()
# Out:
#    movieId                               title
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)

# %%
ratings.head()
# Out:
#    userId  movieId  ratings
# 0       1     1193        5
# 1       1      661        3
# 2       1      914        3
# 3       1     3408        4
# 4       1     2355        5

# %% [markdown]
# # Merge Data Frames

# %%
movie_rating = pd.merge(movies, ratings, on='movieId')
movie_rating.head()
# Out:
#    movieId             title  userId  ratings
# 0        1  Toy Story (1995)       1        5
# 1        1  Toy Story (1995)       6        4
# 2        1  Toy Story (1995)       8        4
# 3        1  Toy Story (1995)       9        5
# 4        1  Toy Story (1995)      10        5

# %%
movie_rating.shape
# Out:
# (1000209, 4)

# %% [markdown]
# # Create Pivot Table

# %%
pivot = movie_rating.pivot_table(index = 'userId', columns = 'title', values = 'ratings')

pivot.head()
# Out:
# title   $1,000,000 Duck (1971)  'Night Mother (1986)  \
# userId
# 1                          NaN                   NaN
# 2                          NaN                   NaN
# 3                          NaN                   NaN
# 4                          NaN                   NaN
# 5                          NaN                   NaN
#
# title   'Til There Was You (1997)  'burbs, The (1989)  \
# userId
# 1                             NaN                 NaN
# 2                             NaN                 NaN
# 3                             NaN                 NaN
# 4                             NaN                 NaN
# 5                             NaN                 NaN
#
# title   ...And Justice for All (1979)  1-900 (1994)  \
# userId
# 1                                 NaN           NaN
# 2                                 NaN           NaN
# 3                                 NaN           NaN
# 4                                 NaN           NaN
# 5                                 NaN           NaN
#
# title   10 Things I Hate About You (1999)  101 Dalmatians (1961)  \
# userId
# 1                                     NaN                    NaN
# 2                                     NaN                    NaN
# 3                                     NaN                    NaN
# 4                                     NaN                    NaN
# 5                                     NaN                    NaN
#
# title   101 Dalmatians (1996)  12 Angry Men (1957)       ...         \
# userId                                                   ...
# 1                         NaN                  NaN       ...
# 2                         NaN                  NaN       ...
# 3                         NaN                  NaN       ...
# 4                         NaN                  NaN       ...
# 5                         NaN                  NaN       ...
#
# title   Young Poisoner's Handbook, The (1995)  Young Sherlock Holmes (1985)  \
# userId
# 1                                         NaN                           NaN
# 2                                         NaN                           NaN
# 3                                         NaN                           NaN
# 4                                         NaN                           NaN
# 5                                         NaN                           NaN
#
# title   Young and Innocent (1937)  Your Friends and Neighbors (1998)  \
# userId
# 1                             NaN                                NaN
# 2                             NaN                                NaN
# 3                             NaN                                NaN
# 4                             NaN                                NaN
# 5                             NaN                                NaN
#
# title   Zachariah (1971)  Zed & Two Noughts, A (1985)  Zero Effect (1998)  \
# userId
# 1                    NaN                          NaN                 NaN
# 2                    NaN                          NaN                 NaN
# 3                    NaN                          NaN                 NaN
# 4                    NaN                          NaN                 NaN
# 5                    NaN                          NaN                 NaN
#
# title   Zero Kelvin (Kj�rlighetens kj�tere) (1995)  Zeus and Roxanne (1997)  \
# userId
# 1                                              NaN                      NaN
# 2                                              NaN                      NaN
# 3                                              NaN                      NaN
# 4                                              NaN                      NaN
# 5                                              NaN                      NaN
#
# title   eXistenZ (1999)
# userId
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
#
# [5 rows x 3706 columns]

# %%
pivot.shape
# Out:
# (6040, 3706)

# %% [markdown]
# # List of all the ratings by the number 1 user (userId 1)

# %%
pivot.loc[1, :].sort_values(ascending = False)
# Out:
# title
# Last Days of Disco, The (1998)                  5.0
# Ben-Hur (1959)                                  5.0
# Mary Poppins (1964)                             5.0
# Dumbo (1941)                                    5.0
# One Flew Over the Cuckoo's Nest (1975)          5.0
# Cinderella (1950)                               5.0
# Pocahontas (1995)                               5.0
# Christmas Story, A (1983)                       5.0
# Bug's Life, A (1998)                            5.0
# Saving Private Ryan (1998)                      5.0
# Schindler's List (1993)                         5.0
# Rain Man (1988)                                 5.0
# Beauty and the Beast (1991)                     5.0
# Toy Story (1995)                                5.0
# Sound of Music, The (1965)                      5.0
# Back to the Future (1985)                       5.0
# Awakenings (1990)                               5.0
# Apollo 13 (1995)                                5.0
# Ferris Bueller's Day Off (1986)                 4.0
# Fargo (1996)                                    4.0
# Erin Brockovich (2000)                          4.0
# Aladdin (1992)                                  4.0
# E.T. the Extra-Terrestrial (1982)               4.0
# Dead Poets Society (1989)                       4.0
# Driving Miss Daisy (1989)                       4.0
# Bambi (1942)                                    4.0
# Antz (1998)                                     4.0
# Girl, Interrupted (1999)                        4.0
# Big (1988)                                      4.0
# Gigi (1958)                                     4.0
#                                                ...
# Wrongfully Accused (1998)                       NaN
# Wyatt Earp (1994)                               NaN
# X-Files: Fight the Future, The (1998)           NaN
# X-Men (2000)                                    NaN
# X: The Unknown (1956)                           NaN
# Xiu Xiu: The Sent-Down Girl (Tian yu) (1998)    NaN
# Yankee Zulu (1994)                              NaN
# Yards, The (1999)                               NaN
# Year My Voice Broke, The (1987)                 NaN
# Year of Living Dangerously (1982)               NaN
# Year of the Horse (1997)                        NaN
# Yellow Submarine (1968)                         NaN
# Yojimbo (1961)                                  NaN
# You Can't Take It With You (1938)               NaN
# You So Crazy (1994)                             NaN
# You've Got Mail (1998)                          NaN
# Young Doctors in Love (1982)                    NaN
# Young Frankenstein (1974)                       NaN
# Young Guns (1988)                               NaN
# Young Guns II (1990)                            NaN
# Young Poisoner's Handbook, The (1995)           NaN
# Young Sherlock Holmes (1985)                    NaN
# Young and Innocent (1937)                       NaN
# Your Friends and Neighbors (1998)               NaN
# Zachariah (1971)                                NaN
# Zed & Two Noughts, A (1985)                     NaN
# Zero Effect (1998)                              NaN
# Zero Kelvin (Kj�rlighetens kj�tere) (1995)      NaN
# Zeus and Roxanne (1997)                         NaN
# eXistenZ (1999)                                 NaN
# Name: 1, Length: 3706, dtype: float64

# %% [markdown]
# # All the ratings for a particular movie (Saving Private Ryan (1998))

# %%
pivot.loc[:, 'Saving Private Ryan (1998)'].sort_values()
# Out:
# userId
# 2813    1.0
# 3993    1.0
# 1495    1.0
# 175     1.0
# 4883    1.0
# 4685    1.0
# 5811    1.0
# 4539    1.0
# 3311    1.0
# 2692    1.0
# 2748    1.0
# 4456    1.0
# 2800    1.0
# 2847    1.0
# 5530    1.0
# 5572    1.0
# 1102    1.0
# 1521    1.0
# 1749    1.0
# 785     1.0
# 3145    1.0
# 3131    1.0
# 3842    1.0
# 5603    1.0
# 5605    1.0
# 3433    2.0
# 4133    2.0
# 1242    2.0
# 4115    2.0
# 2432    2.0
#        ...
# 5995    NaN
# 5996    NaN
# 5997    NaN
# 5999    NaN
# 6000    NaN
# 6001    NaN
# 6004    NaN
# 6005    NaN
# 6006    NaN
# 6011    NaN
# 6012    NaN
# 6013    NaN
# 6014    NaN
# 6015    NaN
# 6016    NaN
# 6017    NaN
# 6019    NaN
# 6020    NaN
# 6021    NaN
# 6025    NaN
# 6026    NaN
# 6028    NaN
# 6029    NaN
# 6030    NaN
# 6031    NaN
# 6032    NaN
# 6034    NaN
# 6035    NaN
# 6038    NaN
# 6039    NaN
# Name: Saving Private Ryan (1998), Length: 6040, dtype: float64

# %% [markdown]
# # Mean of All the ratings for "Saving Private Ryan (1998)" movie

# %%
pivot.loc[:, 'Saving Private Ryan (1998)'].mean()
# Out:
# 4.337353938937053

# %% [markdown]
# # Create Sparse Matrix

# %% [markdown]
# Note: Sparse matrix only keep track of all non NaN values.

# %%
pivot_sparse = sparse.csr_matrix(pivot.fillna(0).values)

# %%
print pivot_sparse
# Out:
#   (0, 84)	4.0
#   (0, 89)	4.0
#   (0, 188)	4.0
#   (0, 195)	5.0
#   (0, 239)	5.0
#   (0, 258)	5.0
#   (0, 277)	4.0
#   (0, 324)	5.0
#   (0, 346)	5.0
#   (0, 376)	4.0
#   (0, 557)	5.0
#   (0, 671)	5.0
#   (0, 679)	5.0
#   (0, 713)	3.0
#   (0, 870)	4.0
#   (0, 988)	4.0
#   (0, 1002)	5.0
#   (0, 1007)	4.0
#   (0, 1054)	4.0
#   (0, 1122)	4.0
#   (0, 1147)	4.0
#   (0, 1331)	4.0
#   (0, 1336)	4.0
#   (0, 1528)	4.0
#   (0, 1611)	4.0
#   :	:
#   (6039, 3458)	4.0
#   (6039, 3476)	4.0
#   (6039, 3479)	4.0
#   (6039, 3504)	4.0
#   (6039, 3511)	4.0
#   (6039, 3517)	3.0
#   (6039, 3518)	4.0
#   (6039, 3526)	2.0
#   (6039, 3541)	3.0
#   (6039, 3548)	3.0
#   (6039, 3551)	4.0
#   (6039, 3574)	1.0
#   (6039, 3575)	1.0
#   (6039, 3578)	5.0
#   (6039, 3583)	4.0
#   (6039, 3596)	5.0
#   (6039, 3608)	5.0
#   (6039, 3615)	1.0
#   (6039, 3641)	5.0
#   (6039, 3655)	4.0
#   (6039, 3656)	5.0
#   (6039, 3659)	5.0
#   (6039, 3662)	4.0
#   (6039, 3685)	5.0
#   (6039, 3693)	4.0

# %% [markdown]
# # Create pairwise distance matrix (Every movie compare to every other movies (correlation))

# %%
distances = pairwise_distances(pivot_sparse.T, metric = 'cosine')

# %%
distances.shape
# Out:
# (3706, 3706)

# %% [markdown]
# # Convert pairwise distance matrix to DataFrame

# %%
distance_df = pd.DataFrame(distances, index = pivot.columns, columns = pivot.columns)

distance_df.head()
# Out:
# title                          $1,000,000 Duck (1971)  'Night Mother (1986)  \
# title
# $1,000,000 Duck (1971)                       0.000000              0.927643
# 'Night Mother (1986)                         0.927643              0.000000
# 'Til There Was You (1997)                    0.962989              0.884710
# 'burbs, The (1989)                           0.920709              0.884455
# ...And Justice for All (1979)                0.939162              0.840474
#
# title                          'Til There Was You (1997)  'burbs, The (1989)  \
# title
# $1,000,000 Duck (1971)                          0.962989            0.920709
# 'Night Mother (1986)                            0.884710            0.884455
# 'Til There Was You (1997)                       0.000000            0.901244
# 'burbs, The (1989)                              0.901244            0.000000
# ...And Justice for All (1979)                   0.933699            0.856380
#
# title                          ...And Justice for All (1979)  1-900 (1994)  \
# title
# $1,000,000 Duck (1971)                              0.939162       1.00000
# 'Night Mother (1986)                                0.840474       1.00000
# 'Til There Was You (1997)                           0.933699       0.91975
# 'burbs, The (1989)                                  0.856380       1.00000
# ...And Justice for All (1979)                       0.000000       1.00000
#
# title                          10 Things I Hate About You (1999)  \
# title
# $1,000,000 Duck (1971)                                  0.941381
# 'Night Mother (1986)                                    0.923202
# 'Til There Was You (1997)                               0.872105
# 'burbs, The (1989)                                      0.807809
# ...And Justice for All (1979)                           0.924907
#
# title                          101 Dalmatians (1961)  101 Dalmatians (1996)  \
# title
# $1,000,000 Duck (1971)                      0.810035               0.827746
# 'Night Mother (1986)                        0.852563               0.904078
# 'Til There Was You (1997)                   0.887346               0.874330
# 'burbs, The (1989)                          0.753073               0.824115
# ...And Justice for All (1979)               0.805846               0.883621
#
# title                          12 Angry Men (1957)       ...         \
# title                                                    ...
# $1,000,000 Duck (1971)                    0.905215       ...
# 'Night Mother (1986)                      0.888587       ...
# 'Til There Was You (1997)                 0.920885       ...
# 'burbs, The (1989)                        0.829281       ...
# ...And Justice for All (1979)             0.794514       ...
#
# title                          Young Poisoner's Handbook, The (1995)  \
# title
# $1,000,000 Duck (1971)                                      0.961275
# 'Night Mother (1986)                                        0.946990
# 'Til There Was You (1997)                                   0.970800
# 'burbs, The (1989)                                          0.886614
# ...And Justice for All (1979)                               0.910002
#
# title                          Young Sherlock Holmes (1985)  \
# title
# $1,000,000 Duck (1971)                             0.923526
# 'Night Mother (1986)                               0.912172
# 'Til There Was You (1997)                          0.937107
# 'burbs, The (1989)                                 0.792103
# ...And Justice for All (1979)                      0.846994
#
# title                          Young and Innocent (1937)  \
# title
# $1,000,000 Duck (1971)                          1.000000
# 'Night Mother (1986)                            0.936242
# 'Til There Was You (1997)                       1.000000
# 'burbs, The (1989)                              0.980038
# ...And Justice for All (1979)                   0.932991
#
# title                          Your Friends and Neighbors (1998)  \
# title
# $1,000,000 Duck (1971)                                  0.955926
# 'Night Mother (1986)                                    0.864038
# 'Til There Was You (1997)                               0.920813
# 'burbs, The (1989)                                      0.861936
# ...And Justice for All (1979)                           0.890971
#
# title                          Zachariah (1971)  Zed & Two Noughts, A (1985)  \
# title
# $1,000,000 Duck (1971)                      1.0                     0.954720
# 'Night Mother (1986)                        1.0                     0.908850
# 'Til There Was You (1997)                   1.0                     0.977406
# 'burbs, The (1989)                          1.0                     0.944296
# ...And Justice for All (1979)               1.0                     0.913920
#
# title                          Zero Effect (1998)  \
# title
# $1,000,000 Duck (1971)                   0.960605
# 'Night Mother (1986)                     0.925213
# 'Til There Was You (1997)                0.920739
# 'burbs, The (1989)                       0.838826
# ...And Justice for All (1979)            0.889133
#
# title                          Zero Kelvin (Kj�rlighetens kj�tere) (1995)  \
# title
# $1,000,000 Duck (1971)                                           1.000000
# 'Night Mother (1986)                                             1.000000
# 'Til There Was You (1997)                                        1.000000
# 'burbs, The (1989)                                               1.000000
# ...And Justice for All (1979)                                    0.925683
#
# title                          Zeus and Roxanne (1997)  eXistenZ (1999)
# title
# $1,000,000 Duck (1971)                        0.879758         0.972997
# 'Night Mother (1986)                          1.000000         0.922193
# 'Til There Was You (1997)                     0.952474         0.936716
# 'burbs, The (1989)                            0.966433         0.889475
# ...And Justice for All (1979)                 1.000000         0.888960
#
# [5 rows x 3706 columns]

# %% [markdown]
# # Comparing 'Saving Private Ryan (1998)' movie to the rest of the movies (Return First 11)

# %%
distance_df.loc[:, 'Saving Private Ryan (1998)'].sort_values()[1:11]
# Out:
# title
# Braveheart (1995)                                        0.345817
# Schindler's List (1993)                                  0.375801
# Matrix, The (1999)                                       0.376191
# Fugitive, The (1993)                                     0.378371
# Shawshank Redemption, The (1994)                         0.385128
# Star Wars: Episode V - The Empire Strikes Back (1980)    0.387776
# Terminator 2: Judgment Day (1991)                        0.390493
# Silence of the Lambs, The (1991)                         0.390791
# Raiders of the Lost Ark (1981)                           0.400807
# Star Wars: Episode IV - A New Hope (1977)                0.404300
# Name: Saving Private Ryan (1998), dtype: float64

# %% [markdown]
# # Building a function that will find movie title's that match with 'Godfather'

# %%
guess = 'Godfather'   
titles = movies.loc[movies['title'].str.contains(guess), 'title'].values
for title in titles:
    print title
    print 'Average Ratings:', pivot[title].mean()
    print 'Number of Ratings:' , pivot[title].count()
    print ''
    print 'Similar movies:', 
    print distance_df[title].sort_values()[1:11]
    print ''
    print ''
# Out:
# Godfather, The (1972)
# Average Ratings: 4.52496626181
# Number of Ratings: 2223
#
# Similar movies: title
# Godfather: Part II, The (1974)                           0.230362
# Star Wars: Episode IV - A New Hope (1977)                0.396638
# Star Wars: Episode V - The Empire Strikes Back (1980)    0.406930
# Raiders of the Lost Ark (1981)                           0.411374
# Fargo (1996)                                             0.423501
# Jaws (1975)                                              0.435121
# Alien (1979)                                             0.445621
# GoodFellas (1990)                                        0.445913
# Saving Private Ryan (1998)                               0.447108
# Terminator, The (1984)                                   0.447472
# Name: Godfather, The (1972), dtype: float64
#
#
# Godfather: Part II, The (1974)
# Average Ratings: 4.35756501182
# Number of Ratings: 1692
#
# Similar movies: title
# Godfather, The (1972)                                    0.230362
# Star Wars: Episode V - The Empire Strikes Back (1980)    0.455428
# Star Wars: Episode IV - A New Hope (1977)                0.456330
# GoodFellas (1990)                                        0.457523
# Raiders of the Lost Ark (1981)                           0.468430
# Fargo (1996)                                             0.469018
# Jaws (1975)                                              0.474542
# Taxi Driver (1976)                                       0.475049
# Alien (1979)                                             0.476770
# French Connection, The (1971)                            0.479491
# Name: Godfather: Part II, The (1974), dtype: float64
#
#
# Godfather: Part III, The (1990)
# Average Ratings: 3.34496124031
# Number of Ratings: 774
#
# Similar movies: title
# Godfather: Part II, The (1974)      0.525698
# Godfather, The (1972)               0.563173
# Heat (1995)                         0.587399
# Ronin (1998)                        0.601461
# GoodFellas (1990)                   0.604447
# Speed (1994)                        0.608344
# Die Hard 2 (1990)                   0.612616
# Patriot Games (1992)                0.618975
# Hunt for Red October, The (1990)    0.623593
# Fugitive, The (1993)                0.626090
# Name: Godfather: Part III, The (1990), dtype: float64

# %% [markdown]
# # Building a function that finds movie title's that match with 'Harry'

# %%
guess = 'Harry'   
titles = movies.loc[movies['title'].str.contains(guess), 'title'].values
for title in titles:
    print title
    print 'Average Ratings:', pivot[title].mean()
    print 'Number of Ratings:' , pivot[title].count()
    print ''
    print 'Similar movies:', 
    print distance_df[title].sort_values(ascending = False)[1:11]
    print ''
    print ''
# Out:
# When Harry Met Sally... (1989)
# Average Ratings: 4.07334183673
# Number of Ratings: 1568
#
# Similar movies: title
# Mutters Courage (1995)                                         1.0
# Mirage (1995)                                                  1.0
# I, Worst of All (Yo, la peor de todas) (1990)                  1.0
# White Boys (1999)                                              1.0
# Rent-a-Kid (1995)                                              1.0
# Scorta, La (1993)                                              1.0
# Resurrection Man (1998)                                        1.0
# In God's Hands (1998)                                          1.0
# Carriers Are Waiting, The (Les Convoyeurs Attendent) (1999)    1.0
# Torso (Corpi Presentano Tracce di Violenza Carnale) (1973)     1.0
# Name: When Harry Met Sally... (1989), dtype: float64
#
#
# Deconstructing Harry (1997)
# Average Ratings: 3.41549295775
# Number of Ratings: 284
#
# Similar movies: title
# Time Tracers (1995)                                         1.0
# Lotto Land (1995)                                           1.0
# Living Dead Girl, The (La Morte Vivante) (1982)             1.0
# Live Virgin (1999)                                          1.0
# Little Indian, Big City (Un indien dans la ville) (1994)    1.0
# Chain of Fools (2000)                                       1.0
# Legal Deceit (1997)                                         1.0
# Leather Jacket Love Story (1997)                            1.0
# Great Locomotive Chase, The (1956)                          1.0
# Alley Cats, The (1968)                                      1.0
# Name: Deconstructing Harry (1997), dtype: float64
#
#
# Trouble with Harry, The (1955)
# Average Ratings: 3.59863945578
# Number of Ratings: 147
#
# Similar movies: title
# Big Squeeze, The (1996)             1.0
# Boy Called Hate, A (1995)           1.0
# Six Ways to Sunday (1997)           1.0
# Skipped Parts (2000)                1.0
# Slappy and the Stinkers (1998)      1.0
# Slaves to the Underground (1997)    1.0
# Sleepover (1995)                    1.0
# Smashing Time (1967)                1.0
# Smoking/No Smoking (1993)           1.0
# Snowriders (1996)                   1.0
# Name: Trouble with Harry, The (1955), dtype: float64
#
#
# Who's Harry Crumb? (1989)
# Average Ratings: 2.7225433526
# Number of Ratings: 173
#
# Similar movies: title
# Bonheur, Le (1965)            1.0
# Merry War, A (1997)           1.0
# Born to Win (1971)            1.0
# Bossa Nova (1999)             1.0
# Boy Called Hate, A (1995)     1.0
# Boys (1996)                   1.0
# Hangmen Also Die (1943)       1.0
# Boys Life 2 (1997)            1.0
# Eaten Alive (1976)            1.0
# Hanging Garden, The (1997)    1.0
# Name: Who's Harry Crumb? (1989), dtype: float64
#
#
# Harry and the Hendersons (1987)
# Average Ratings: 2.71812080537
# Number of Ratings: 298
#
# Similar movies: title
# Leather Jacket Love Story (1997)    1.0
# Soft Toilet Seats (1999)            1.0
# Grosse Fatigue (1994)               1.0
# Something to Sing About (1937)      1.0
# Condition Red (1995)                1.0
# Song of Freedom (1936)              1.0
# Sonic Outlaws (1995)                1.0
# Hanging Garden, The (1997)          1.0
# Color Me Blood Red (1965)           1.0
# Ulysses (Ulisse) (1954)             1.0
# Name: Harry and the Hendersons (1987), dtype: float64
#
#
# Let's Get Harry (1986)
# Average Ratings: 2.71052631579
# Number of Ratings: 38
#
# Similar movies: title
# Late Bloomers (1996)                                               1.0
# Kids of the Round Table (1995)                                     1.0
# Kika (1993)                                                        1.0
# King and I, The (1999)                                             1.0
# Kissed (1996)                                                      1.0
# Knock Off (1998)                                                   1.0
# Zeus and Roxanne (1997)                                            1.0
# Ladybird Ladybird (1994)                                           1.0
# Lamerica (1994)                                                    1.0
# Last Klezmer: Leopold Kozlowski, His Life and Music, The (1995)    1.0
# Name: Let's Get Harry (1986), dtype: float64

# %% [markdown]
# # Building a function that finds movie title's that match with 'Alien'

# %%
guess = 'Alien'  
titles = movies.loc[movies['title'].str.contains(guess), 'title'].values
for title in titles:
    print title
    print 'Average Ratings:', pivot[title].mean()
    print 'Number of Ratings:' , pivot[title].count()
    print ''
    print 'Similar movies:', 
    print distance_df[title].sort_values()[1:11]
    print ''
    print ''
# Out:
# Aliens (1986)
# Average Ratings: 4.12582417582
# Number of Ratings: 1820
#
# Similar movies: title
# Alien (1979)                                             0.256007
# Terminator, The (1984)                                   0.259805
# Star Wars: Episode V - The Empire Strikes Back (1980)    0.317103
# Predator (1987)                                          0.330657
# Terminator 2: Judgment Day (1991)                        0.346826
# Blade Runner (1982)                                      0.355283
# Star Wars: Episode IV - A New Hope (1977)                0.355760
# Star Wars: Episode VI - Return of the Jedi (1983)        0.367781
# Matrix, The (1999)                                       0.368420
# Total Recall (1990)                                      0.376522
# Name: Aliens (1986), dtype: float64
#
#
# Alien (1979)
# Average Ratings: 4.15958498024
# Number of Ratings: 2024
#
# Similar movies: title
# Aliens (1986)                                            0.256007
# Terminator, The (1984)                                   0.293836
# Star Wars: Episode IV - A New Hope (1977)                0.316135
# Star Wars: Episode V - The Empire Strikes Back (1980)    0.345038
# Blade Runner (1982)                                      0.358081
# Jaws (1975)                                              0.359424
# Terminator 2: Judgment Day (1991)                        0.371797
# Matrix, The (1999)                                       0.387275
# 2001: A Space Odyssey (1968)                             0.392283
# Total Recall (1990)                                      0.393188
# Name: Alien (1979), dtype: float64
#
#
# Alien� (1992)
# Average Ratings: 3.03783783784
# Number of Ratings: 925
#
# Similar movies: title
# Alien: Resurrection (1997)               0.313717
# Aliens (1986)                            0.461211
# Starship Troopers (1997)                 0.476600
# Alien (1979)                             0.478269
# Stargate (1994)                          0.484676
# Predator 2 (1990)                        0.488316
# Fifth Element, The (1997)                0.489230
# Total Recall (1990)                      0.493752
# Independence Day (ID4) (1996)            0.496447
# Lost World: Jurassic Park, The (1997)    0.499793
# Name: Alien� (1992), dtype: float64
#
#
# Alien: Resurrection (1997)
# Average Ratings: 2.95892169448
# Number of Ratings: 779
#
# Similar movies: title
# Alien� (1992)                            0.313717
# Fifth Element, The (1997)                0.478190
# Species (1995)                           0.483863
# Stargate (1994)                          0.487800
# Aliens (1986)                            0.493933
# Starship Troopers (1997)                 0.495344
# Alien (1979)                             0.513941
# Independence Day (ID4) (1996)            0.514938
# Predator 2 (1990)                        0.519036
# Lost World: Jurassic Park, The (1997)    0.527445
# Name: Alien: Resurrection (1997), dtype: float64
#
#
# Alien Escape (1995)
# Average Ratings: 2.55
# Number of Ratings: 20
#
# Similar movies: title
# Snowriders (1996)                                    0.805675
# Steel (1997)                                         0.856058
# Return of the Texas Chainsaw Massacre, The (1994)    0.872746
# Body Snatchers (1993)                                0.873722
# Alien: Resurrection (1997)                           0.874257
# Species II (1998)                                    0.882766
# Bats (1999)                                          0.892307
# Hellraiser III: Hell on Earth (1992)                 0.893964
# Alien� (1992)                                        0.895163
# Leatherface: Texas Chainsaw Massacre III (1990)      0.895369
# Name: Alien Escape (1995), dtype: float64
#
#
# Alien Nation (1988)
# Average Ratings: 3.22420634921
# Number of Ratings: 504
#
# Similar movies: title
# Running Man, The (1987)                       0.528919
# Mad Max Beyond Thunderdome (1985)             0.549369
# Starman (1984)                                0.557912
# Robocop (1987)                                0.560358
# Star Trek IV: The Voyage Home (1986)          0.566449
# Aliens (1986)                                 0.568207
# Star Trek III: The Search for Spock (1984)    0.568523
# Cocoon (1985)                                 0.569563
# Predator (1987)                               0.572310
# Back to the Future Part II (1989)             0.573067
# Name: Alien Nation (1988), dtype: float64
